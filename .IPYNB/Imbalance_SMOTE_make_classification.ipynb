# %%
# %mamba install scikit-learn imbalanced-learn
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, scikit-learn, imbalanced-learn
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 5.244800000000745 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# + brotli-python                 1.2.0                         py313h33caa6c_0               emscripten-forge
# + certifi                       2026.4.22                     pyhd8ed1ab_0                  conda-forge
# + charset-normalizer            3.4.7                         pyhd8ed1ab_0                  conda-forge
# + idna                          3.13                          pyhcf101f3_0                  conda-forge
# + imbalanced-learn              0.14.1                        pyhd8ed1ab_0                  conda-forge
# + joblib                        1.5.3                         py313h1804a44_1               emscripten-forge
# + pysocks                       1.7.1                         py313h1804a44_2               emscripten-forge
# + requests                      2.34.2                        pyhcf101f3_0                  conda-forge
# + scikit-learn                  1.8.0                         np22py313h2c67255_3           emscripten-forge
# + setuptools                    82.0.1                        pyh332efcf_0                  conda-forge
# + sklearn-compat                0.1.5                         pyhd8ed1ab_0                  conda-forge
# + threadpoolctl                 3.6.0                         pyhecae5ae_0                  conda-forge
# + urllib3                       2.2.2                         pyhd8ed1ab_0                  conda-forge
# - pip                           25.3                          pyh145f28c_0                  conda-forge

# %% [markdown]
# ## SMOTE on Imbalanced Classification Dataset

# %%
from imblearn.over_sampling import SMOTE
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
# Generate an imbalanced classification dataset
X, y = make_classification(n_samples=10000, weights=[0.95], flip_y=0, random_state=2)
print(X)
# Out:
# [[ 0.47052471 -1.8726147   0.53299835 ... -1.35383166  1.34886053
#    0.16275421]
#  [ 1.08885827 -0.10703172 -0.39565297 ...  0.14467816 -1.66157502
#    0.31016641]
#  [-0.55509827  0.54249876  0.60868109 ...  0.62538616  1.88987601
#   -0.33484788]
#  ...
#  [ 2.16325923  2.57550532 -0.49688732 ... -0.82212553 -1.24581207
#    2.34452212]
#  [ 1.0814028   0.17145678 -0.188339   ...  0.26415833  0.69967919
#    0.41363207]
#  [ 1.01208655 -0.8945138   0.6599338  ...  0.98372444 -0.53366514
#   -0.74453764]]

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# Apply SMOTE to the training set
smote = SMOTE()
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
print(y_train.shape)
# Out:
# (8000,)

# %%
# Train models — with and without SMOTE
model = LogisticRegression()
model1 = LogisticRegression()

model.fit(X_train, y_train)
model1.fit(X_train_resampled, y_train_resampled)

# Evaluate on the test set
y_pred = model.predict(X_test)
y_pred_res = model1.predict(X_test)

print("STATS-WITHOUT SMOTE")
print(classification_report(y_test, y_pred))
print("STATS-WITH SMOTE")
print(classification_report(y_test, y_pred_res))

print(accuracy_score(y_test, y_pred))
print(accuracy_score(y_test, y_pred_res))
# Out:
# STATS-WITHOUT SMOTE
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1911
#            1       0.92      0.82      0.87        89
#
#     accuracy                           0.99      2000
#    macro avg       0.96      0.91      0.93      2000
# weighted avg       0.99      0.99      0.99      2000
#
# STATS-WITH SMOTE
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98      1911
#            1       0.51      0.96      0.66        89
#
#     accuracy                           0.96      2000
#    macro avg       0.75      0.96      0.82      2000
# weighted avg       0.98      0.96      0.96      2000
#
# 0.989
# 0.957
