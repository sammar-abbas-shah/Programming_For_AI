# %% [markdown]
# # KFold Demo — Logistic Regression on Custom Dataset
# Applies KFold cross-validation with a real model and prints accuracy per fold.

# %%
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
# Student pass/fail based on marks (PF) and attendance (Att)
dic = {
    'PF':     [90,50,40,60,30,70,30,20,80,50,60,80,90],
    'Att':    [60,50,70,50,30,40,60,35,20,60,40,30,70],
    'Result': [1, 1, 1, 1, 0, 0, 0, 0, 0, 1, 1, 0, 1]   # 1=Pass, 0=Fail
}
dataset = pd.DataFrame(dic)
dataset
# Out:
#     PF  Att  Result
# 0   90   60       1
# 1   50   50       1
# 2   40   70       1
# 3   60   50       1
# 4   30   30       0
# 5   70   40       0
# 6   30   60       0
# 7   20   35       0
# 8   80   20       0
# 9   50   60       1
# 10  60   40       1
# 11  80   30       0
# 12  90   70       1

# %%
X = dataset.iloc[:, :-1]   # features: PF, Att
y = dataset['Result']      # target: pass/fail

# %%
model = LogisticRegression(max_iter=1000)
kf = KFold(n_splits=6)     # 6 folds over 13 rows

for fold, (train_idx, test_idx) in enumerate(kf.split(X), start=1):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    print(f'Fold {fold} | Test rows: {test_idx} | Accuracy: {acc}')
# Out:
# Fold 1 | Test rows: [0 1 2] | Accuracy: 0.6666666666666666
# Fold 2 | Test rows: [3 4] | Accuracy: 1.0
# Fold 3 | Test rows: [5 6] | Accuracy: 0.0
# Fold 4 | Test rows: [7 8] | Accuracy: 1.0
# Fold 5 | Test rows: [ 9 10] | Accuracy: 0.5
# Fold 6 | Test rows: [11 12] | Accuracy: 1.0
