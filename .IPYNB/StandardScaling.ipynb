# %%
# %mamba install scikit-learn pandas numpy
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, scikit-learn
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 4.9695 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# + brotli-python                 1.2.0                         py313h33caa6c_0               emscripten-forge
# + certifi                       2026.4.22                     pyhd8ed1ab_0                  conda-forge
# + charset-normalizer            3.4.7                         pyhd8ed1ab_0                  conda-forge
# + idna                          3.13                          pyhcf101f3_0                  conda-forge
# + joblib                        1.5.3                         py313h1804a44_1               emscripten-forge
# + pysocks                       1.7.1                         py313h1804a44_2               emscripten-forge
# + requests                      2.34.2                        pyhcf101f3_0                  conda-forge
# + scikit-learn                  1.8.0                         np22py313h2c67255_3           emscripten-forge
# + setuptools                    82.0.1                        pyh332efcf_0                  conda-forge
# + threadpoolctl                 3.6.0                         pyhecae5ae_0                  conda-forge
# + urllib3                       2.2.2                         pyhd8ed1ab_0                  conda-forge
# - pip                           25.3                          pyh145f28c_0                  conda-forge

# %% [markdown]
# ## Standard Scaling (Z-Score Normalization)
# Formula: `Xnew = (X - mean) / SD`

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

# %%
dataset = pd.DataFrame(
    {
        "Age":[30,20,40,50,33,23,34,60,45,32],
        "SemNo":[1,5,6,2,3,7,8,9,3,2],
        "Attendance":[90,34,89,70,60,50,78,88,99,100]
    }
)

# %%
# Method 1 — Manual Z-score normalization
def zscore_normalizer(df):
    normalized_df = df.copy()
    for column in df.columns:
        mean_val = df[column].mean()
        std_dev = df[column].std()
        normalized_df[column] = (df[column] - mean_val) / std_dev
    return normalized_df

normalized_df = zscore_normalizer(dataset)

print('=============Without SKLearn================')
print("Original DataFrame:")
print(dataset)
print("\nNormalized DataFrame (Z-score):")
print(normalized_df)
print('=============Without SKLearn================')
# Out:
# =============Without SKLearn================
# Original DataFrame:
#    Age  SemNo  Attendance
# 0   30      1          90
# 1   20      5          34
# 2   40      6          89
# 3   50      2          70
# 4   33      3          60
# 5   23      7          50
# 6   34      8          78
# 7   60      9          88
# 8   45      3          99
# 9   32      2         100
#
# Normalized DataFrame (Z-score):
#         Age     SemNo  Attendance
# 0 -0.546224 -1.287174    0.645929
# 1 -1.361483  0.143019   -1.901397
# 2  0.269036  0.500568    0.600441
# 3  1.084295 -0.929626   -0.263830
# 4 -0.301646 -0.572078   -0.718710
# 5 -1.116906  0.858116   -1.173590
# 6 -0.220120  1.215665    0.100074
# 7  1.899555  1.573213    0.554953
# 8  0.676665 -0.572078    1.055321
# 9 -0.383172 -0.929626    1.100809
# =============Without SKLearn================

# %%
# Method 2 — Using sklearn StandardScaler
print('=============With SK-learn StandScaler================')
sScaler = StandardScaler()
dataset_scaled1 = sScaler.fit_transform(dataset)
dataset_scaled1 = pd.DataFrame(dataset_scaled1, columns=dataset.columns)
print(dataset_scaled1)
# Out:
# =============With SK-learn StandScaler================
#         Age     SemNo  Attendance
# 0 -0.575771 -1.356801    0.680869
# 1 -1.435130  0.150756   -2.004249
# 2  0.283588  0.527645    0.632921
# 3  1.142947 -0.979912   -0.278102
# 4 -0.317963 -0.603023   -0.757587
# 5 -1.177322  0.904534   -1.237072
# 6 -0.232027  1.281423    0.105487
# 7  2.002306  1.658312    0.584972
# 8  0.713268 -0.603023    1.112406
# 9 -0.403899 -0.979912    1.160355

# %%
# Cross-check: compare both methods
difference = pd.DataFrame()
for feature in dataset.columns:
    difference[feature+'_D'] = np.where(
        round(normalized_df[feature], 4) == round(dataset_scaled1[feature], 4), 0, 1
    )
print(difference.sum())
# Out:
# Age_D           10
# SemNo_D         10
# Attendance_D    10
# dtype: int64
