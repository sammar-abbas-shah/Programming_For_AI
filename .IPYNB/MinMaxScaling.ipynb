# %%
# %mamba install numpy pandas scikit-learn
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, scikit-learn
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 4.212700000000186 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# + brotli-python                 1.2.0                         py313h33caa6c_0               emscripten-forge
# + certifi                       2026.4.22                     pyhd8ed1ab_0                  conda-forge
# + charset-normalizer            3.4.7                         pyhd8ed1ab_0                  conda-forge
# + idna                          3.13                          pyhcf101f3_0                  conda-forge
# + joblib                        1.5.3                         py313h1804a44_1               emscripten-forge
# + pandas                        3.0.2                         np22py313h9d9dc1e_0           emscripten-forge
# + pysocks                       1.7.1                         py313h1804a44_2               emscripten-forge
# + python-tzdata                 2026.2                        pyhd8ed1ab_0                  conda-forge
# + requests                      2.34.2                        pyhcf101f3_0                  conda-forge
# + scikit-learn                  1.8.0                         np22py313h2c67255_3           emscripten-forge
# + setuptools                    82.0.1                        pyh332efcf_0                  conda-forge
# + threadpoolctl                 3.6.0                         pyhecae5ae_0                  conda-forge
# + urllib3                       2.2.2                         pyhd8ed1ab_0                  conda-forge
# - pip                           25.3                          pyh145f28c_0                  conda-forge

# %% [markdown]
# ## Min-Max Scaling (Normalization)
# Formula: `NewVal = (CurVal - Xmin) / (Xmax - Xmin)`

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
dataset = pd.DataFrame(
    {
        "Age":[30,20,40,50,33,23,34,60,45,32],
        "SemNo":[1,5,6,2,3,7,8,9,3,2],
        "Attendance":[90,34,89,70,60,50,78,88,99,100]
    }
)

# %%
# Method 1 — Manual Min-Max Scaling
def minmax_scaler(df):
    scaled_df = df.copy()
    for column in df.columns:
        min_val = df[column].min()
        max_val = df[column].max()
        scaled_df[column] = (df[column] - min_val) / (max_val - min_val)
    return scaled_df

scaled_df = minmax_scaler(dataset)

print('=============Without SKLearn================')
print("Original DataFrame:")
print(dataset)
print("\nScaled DataFrame:")
print(scaled_df)
print('=============Without SKLearn================')
# Out:
# =============Without SKLearn================
# Original DataFrame:
#    Age  SemNo  Attendance
# 0   30      1          90
# 1   20      5          34
# 2   40      6          89
# 3   50      2          70
# 4   33      3          60
# 5   23      7          50
# 6   34      8          78
# 7   60      9          88
# 8   45      3          99
# 9   32      2         100
#
# Scaled DataFrame:
#      Age  SemNo  Attendance
# 0  0.250  0.000    0.848485
# 1  0.000  0.500    0.000000
# 2  0.500  0.625    0.833333
# 3  0.750  0.125    0.545455
# 4  0.325  0.250    0.393939
# 5  0.075  0.750    0.242424
# 6  0.350  0.875    0.666667
# 7  1.000  1.000    0.818182
# 8  0.625  0.250    0.984848
# 9  0.300  0.125    1.000000
# =============Without SKLearn================

# %%
# Method 2 — Using sklearn MinMaxScaler
print('=============With SK-learn MinMax================')
mmScaler = MinMaxScaler()
dataset_scaled1 = mmScaler.fit_transform(dataset)
dataset_scaled1 = pd.DataFrame(dataset_scaled1, columns=dataset.columns)
print(dataset_scaled1)
# Out:
# =============With SK-learn MinMax================
#      Age  SemNo  Attendance
# 0  0.250  0.000    0.848485
# 1  0.000  0.500    0.000000
# 2  0.500  0.625    0.833333
# 3  0.750  0.125    0.545455
# 4  0.325  0.250    0.393939
# 5  0.075  0.750    0.242424
# 6  0.350  0.875    0.666667
# 7  1.000  1.000    0.818182
# 8  0.625  0.250    0.984848
# 9  0.300  0.125    1.000000
