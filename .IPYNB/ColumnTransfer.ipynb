# %% [markdown]
# ## Column Transformer
# Applies OrdinalEncoder, OneHotEncoder, and LabelEncoder to the covid_toy dataset using sklearn's ColumnTransformer.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('covid_toy.csv')
print(df.head())

# Check for missing values
print(df.isnull().sum())
# Out:
#    age  gender  fever cough        city has_covid
# 0   60    Male  103.0  Mild   Islamabad        No
# 1   27    Male  100.0  Mild  Rawalpindi       Yes
# 2   42    Male  101.0  Mild  Rawalpindi        No
# 3   31  Female   98.0  Mild   Islamabad        No
# 4   65  Female  101.0  Mild      Multan        No
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
# Apply transformations to the appropriate columns
transformer = ColumnTransformer(transformers=[
   # ('tnf1', SimpleImputer(), ['fever']),  # Impute missing values in 'fever'
    ('tnf2', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough']),
    ('tnf3', OneHotEncoder(sparse_output=False, drop='first'), ['gender', 'city']),
], remainder='passthrough')

# Transform the features
data_encoded = transformer.fit_transform(df)
print(type(data_encoded))

# Print the shape of the transformed data
print(data_encoded.shape)
# Out:
# <class 'numpy.ndarray'>
# (100, 8)

# %%
# If 'has_covid' is the target column, apply LabelEncoder separately
label_encoder = LabelEncoder()

# df['has_covid'] = label_encoder.fit_transform(data_encoded['has_covid'])
# data_encoded[7] = label_encoder.fit_transform(data_encoded[7])

# Display the encoded target column
# print(data_encoded)
